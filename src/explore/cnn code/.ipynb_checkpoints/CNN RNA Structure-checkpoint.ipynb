# %% [markdown]
# # Convolutional Neural Network for RNA Structure Prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
import prepare_data as data
import time

# %%
filename_train_src = '/Users/harrisonlabollita/Library/Mobile Documents/com~apple~CloudDocs/Arizona State University/Sulc group/src/code/RNAtrain_src.txt'
filename_train_tgt = '/Users/harrisonlabollita/Library/Mobile Documents/com~apple~CloudDocs/Arizona State University/Sulc group/src/code/RNAtrain_tgt.txt'
filename_test_src = '/Users/harrisonlabollita/Library/Mobile Documents/com~apple~CloudDocs/Arizona State University/Sulc group/src/code/RNAtest_src.txt'
filename_test_tgt = '/Users/harrisonlabollita/Library/Mobile Documents/com~apple~CloudDocs/Arizona State University/Sulc group/src/code/RNAtest_tgt.txt'

# %%
train_src = np.array(data.RNAsequences(filename_train_src))
train_tgt = np.array(data.structureRep(filename_train_tgt))
test_src = np.array(data.RNAsequences(filename_test_src))
test_tgt = np.array(data.structureRep(filename_test_tgt))

data.training_information(train_src, test_src)

start = time.time()
print('Converting training sequences to matrices')
train_src = data.seqs2matrices(train_src)
print('Done!')
print('Converting testing sequences to matrices')
test_src = data.seqs2matrices(test_src)
print('Done!')
end = time.time()
print('Sequence to matrices total time: %0.3f'%(end - start))
# Out:
# DATASET INFO
# Number of sequences in training set: 80000
# Number of sequences in testing set: 20000
# Length of sequences: 30
# Converting training sequences to matrices
# Done!
# Converting testing sequences to matrices
# Done!
# Sequence to matrices total time: 863.403

# %%
plt.figure()
fig, ax = plt.subplots(1,5, figsize = (20,8))
ax[0].imshow(train_src[0], cmap = 'binary')
ax[1].imshow(train_src[1], cmap = 'binary')
ax[2].imshow(train_src[2], cmap = 'binary')
ax[3].imshow(train_src[3], cmap = 'binary')
ax[4].imshow(train_src[4], cmap = 'binary')
plt.show()

# %%
import model as cnn
train_src_1 = train_src.reshape(len(train_src[:10000]), 30, 30, 1)
train_tgt_1 = train_tgt[:10000]
test_src_1 = test_src.reshape(len(test_src[:1000]), 30, 30, 1)
test_tgt_1 = test_tgt[:1000]
model, history = cnn.Model(train_src, train_tgt, test_src, test_tgt)
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b840edd1da4d> in <module>()
#       2 train_src = train_src.reshape(len(train_src), 30, 30, 1)
#       3 test_src = test_src.reshape(len(test_src), 30, 30, 1)
# ----> 4 model, history = cnn.Model(train_src, train_tgt, test_src, test_tgt)
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/Arizona State University/Sulc group/src/cnn code/model.py in Model(x_train, y_train, x_test, y_test)
#      14     model.add(Conv2D(16, (3, 3), activation = 'relu'))
#      15     model.add(MaxPooling2D(pool_size = (3, 3)))
# ---> 16     model.add(Conv2D(16, (3,3), actiavtion = 'relu'))
#      17     model.add(MaxPoolin2D(pool_size = (3,3)))
#      18     model.add(Flatten())
#
# /anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/convolutional.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     463             kernel_constraint=kernel_constraint,
#     464             bias_constraint=bias_constraint,
# --> 465             **kwargs)
#     466         self.input_spec = InputSpec(ndim=4)
#     467
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/convolutional.py in __init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     102                  bias_constraint=None,
#     103                  **kwargs):
# --> 104         super(_Conv, self).__init__(**kwargs)
#     105         self.rank = rank
#     106         self.filters = filters
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/topology.py in __init__(self, **kwargs)
#     291         for kwarg in kwargs:
#     292             if kwarg not in allowed_kwargs:
# --> 293                 raise TypeError('Keyword argument not understood:', kwarg)
#     294         name = kwargs.get('name')
#     295         if not name:
#
# TypeError: ('Keyword argument not understood:', 'actiavtion')

# %%
score = model.evaluate(test_src, test_tgt, verbose = 0)
print('Model Performance: Loss %.2f' %(score[0]))
print('Model Performance: Accuracy %.5f' %(score[1]))
# Out:
# Model Performance: Loss 0.81
# Model Performance: Accuracy 0.81460

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(history.history['acc'], label = 'Train')
ax[0].plot(history.history['val_acc'], label = 'Test')
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc = 'best')

ax[1].plot(history.history['loss'], label = 'Train')
ax[1].plot(history.history['val_loss'],label = 'Test')
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc = 'best')
plt.show()

# %%
# Out:
# 0
